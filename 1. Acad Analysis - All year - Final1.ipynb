# %%
import csv
import pandas as pd
import numpy as np 
import os
import nltk
import re
from nltk import word_tokenize

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')

# %%
df0 = pd.read_csv("/Users/yaminirege/Desktop/E2014.csv")
df1 = pd.read_csv("/Users/yaminirege/Desktop/2.2015.csv")
df2 = pd.read_csv("/Users/yaminirege/Desktop/3.2016.csv")
df3 = pd.read_csv("/Users/yaminirege/Desktop/4.2017.csv")
df4 = pd.read_csv("/Users/yaminirege/Desktop/5.2018.csv")
df5 = pd.read_csv("/Users/yaminirege/Desktop/6.2019.csv")
df6 = pd.read_csv("/Users/yaminirege/Desktop/7.2020.csv")

# %%
df0.head()
# Out:
#    ID          Terms Class (BOT) Major  Conc  Coop Citizenship  \
# 0   6  201435-201445          SR  ACCT  4COP     0  US Citizen
# 1  11  201415-201425          JR   FIN  4COP     0  US Citizen
# 2  25  201435-201445          JR  GBUS  4COP     0  US Citizen
# 3  37  201435-201445          SR  LGST  5COP     2  US Citizen
# 4  44  201435-201445          SO   BAE  5COP     1  US Citizen
#
#                                            Strengths  \
# 0  [Student's] strengths include the ability to m...
# 1  Demonstrates knowledge in compiling and analyz...
# 2  [Student] is detail-oriented, customer-focused...
# 3  Excellent attention to detail and work ethic. ...
# 4  Communication skills, leadership, lead by example
#
#                                             Weakness  \
# 0  In the time that I worked with [Student] - the...
# 1  Improvement needed in areas of following proto...
# 2  Opportunity exists for [Student] to know his a...
# ...

# %%
from nltk.corpus import stopwords
import string
string.punctuation
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
df0['Acad'].str.lower()
df1['Acad'].str.lower()
df2['Acad'].str.lower()
df3['Acad'].str.lower()
df4['Acad'].str.lower()
df5['Acad'].str.lower()
df6['Acad'].str.lower()
# Out:
# 0                                                     na
# 1                                                    NaN
# 2      just continue on the path of learning and take...
# 3                                                    NaN
# 4                                                   none
#                              ...
# 700                                                 none
# 701                                                 none
# 702    no changes recommended, our industry does not ...
# 703    introduce more real-life situational accountin...
# 704    a few hospitality subjects to go with his degr...
# Name: Acad, Length: 705, dtype: object

# %%
df0['Acad'] = df0['Acad'].str.lower()
df1['Acad'] = df1['Acad'].str.lower()
df2['Acad'] = df2['Acad'].str.lower()
df3['Acad'] = df3['Acad'].str.lower()
df4['Acad'] = df4['Acad'].str.lower()
df5['Acad'] = df5['Acad'].str.lower()
df6['Acad'] = df6['Acad'].str.lower()

# %%
df0["Acad"] = df0['Acad'].str.replace('[^\w\s]','')
df1["Acad"] = df1['Acad'].str.replace('[^\w\s]','')
df2["Acad"] = df2['Acad'].str.replace('[^\w\s]','')
df3["Acad"] = df3['Acad'].str.replace('[^\w\s]','')
df4["Acad"] = df4['Acad'].str.replace('[^\w\s]','')
df5["Acad"] = df5['Acad'].str.replace('[^\w\s]','')
df6["Acad"] = df6['Acad'].str.replace('[^\w\s]','')
# Out:
# /var/folders/l5/9067kgk145b21q5rd2bjtvcc0000gn/T/ipykernel_14203/1767907912.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df0["Acad"] = df0['Acad'].str.replace('[^\w\s]','')
# /var/folders/l5/9067kgk145b21q5rd2bjtvcc0000gn/T/ipykernel_14203/1767907912.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df1["Acad"] = df1['Acad'].str.replace('[^\w\s]','')
# /var/folders/l5/9067kgk145b21q5rd2bjtvcc0000gn/T/ipykernel_14203/1767907912.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df2["Acad"] = df2['Acad'].str.replace('[^\w\s]','')
# /var/folders/l5/9067kgk145b21q5rd2bjtvcc0000gn/T/ipykernel_14203/1767907912.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df3["Acad"] = df3['Acad'].str.replace('[^\w\s]','')
# ...

# %%
df0['Acad_R'] = df0['Acad'].str.replace("students","")

# %%
df0['Acad_R'] = df0['Acad_R'].str.replace("student","")
df0['Acad_R'] = df0['Acad_R'].str.replace("course","")
df0['Acad_R'] = df0['Acad_R'].str.replace("college","")
df0['Acad_R'] = df0['Acad_R'].str.replace("coop","")
df0['Acad_R'] = df0['Acad_R'].str.replace("preparation","")
df0['Acad_R'] = df0['Acad_R'].str.replace("additional","")
df0['Acad_R'] = df0['Acad_R'].str.replace("better","")
df0['Acad_R'] = df0['Acad_R'].str.replace("understanding","")
df0['Acad_R'] = df0['Acad_R'].str.replace("continued","")
df0['Acad_R'] = df0['Acad_R'].str.replace("skill","")
df0['Acad_R'] = df0['Acad_R'].str.replace("believe","")
df0['Acad_R'] = df0['Acad_R'].str.replace("suggest","")
df0['Acad_R'] = df0['Acad_R'].str.replace("improvement","")
df0['Acad_R'] = df0['Acad_R'].str.replace("improve","")
df0['Acad_R'] = df0['Acad_R'].str.replace("incorporate","")
df0['Acad_R'] = df0['Acad_R'].str.replace("more","")
df0['Acad_R'] = df0['Acad_R'].str.replace("drexel","")
df0['Acad_R'] = df0['Acad_R'].str.replace("none","")
df0['Acad_R'] = df0['Acad_R'].str.replace("would","")
df0['Acad_R'] = df0['Acad_R'].str.replace("work","")
df0['Acad_R'] = df0['Acad_R'].str.replace("need","")
df0['Acad_R'] = df0['Acad_R'].str.replace("help","")
df0['Acad_R'] = df0['Acad_R'].str.replace("like","")
df0['Acad_R'] = df0['Acad_R'].str.replace("also","")
df0['Acad_R'] = df0['Acad_R'].str.replace("helpful","")
df0['Acad_R'] = df0['Acad_R'].str.replace("feel","")
df0['Acad_R'] = df0['Acad_R'].str.replace("continue","")
df0['Acad_R'] = df0['Acad_R'].str.replace("see","")
df0['Acad_R'] = df0['Acad_R'].str.replace("seemed","")
df0['Acad_R'] = df0['Acad_R'].str.replace("little","")
df0['Acad_R'] = df0['Acad_R'].str.replace("namely","")
df0['Acad_R'] = df0['Acad_R'].str.replace("doesnt","")
df0['Acad_R'] = df0['Acad_R'].str.replace("class","")
df0['Acad_R'] = df0['Acad_R'].str.replace("apply","")
df0['Acad_R'] = df0['Acad_R'].str.replace("ensure","")
df0['Acad_R'] = df0['Acad_R'].str.replace("either","")
df0['Acad_R'] = df0['Acad_R'].str.replace("already","")
df0['Acad_R'] = df0['Acad_R'].str.replace("use","")

# %%
df0_1 = df0.drop(['Strengths', 'Weakness', 'Merged1'], axis=1)

# %%
df0_1.head()
# Out:
#    ID          Terms Class (BOT) Major  Conc  Coop Citizenship  \
# 0   6  201435-201445          SR  ACCT  4COP     0  US Citizen
# 1  11  201415-201425          JR   FIN  4COP     0  US Citizen
# 2  25  201435-201445          JR  GBUS  4COP     0  US Citizen
# 3  37  201435-201445          SR  LGST  5COP     2  US Citizen
# 4  44  201435-201445          SO   BAE  5COP     1  US Citizen
#
#                                                 Acad  \
# 0                                               none
# 1  student needs a strong role model to help him ...
# 2  training or a course on corporate communicatio...
# 3                                               none
# 4                                               none
#
#                                               Acad_R
# 0
# 1   s a strong role model to  him  focusing on hi...
# 2  training or a  on corporate communication  be ...
# 3
# 4

# %%
import string
mess = 'sample message!...'
nopunc=[char for char in mess if char not in string.punctuation]
nopunc=''.join(nopunc)
print(nopunc)
# Out:
# sample message

# %%
nopunc.split()
# Out:
# ['sample', 'message']

# %%
clean_mess=[word for word in nopunc.split() if word.lower() not in stopwords.words('english')]

# %%
def text_process(mess):
    nopunc =[char for char in mess if char not in string.punctuation]
    nopunc=''.join(nopunc)
    return [word for word in nopunc.split() if word.lower() not in stopwords.words('english')]

# %%
# Printing lists of tokens (also known as lemmas) 
df0_1['Acad_R'] = df0_1['Acad_R'].apply(text_process)

# %%
df0_1.head()
# Out:
#    ID          Terms Class (BOT) Major  Conc  Coop Citizenship  \
# 0   6  201435-201445          SR  ACCT  4COP     0  US Citizen
# 1  11  201415-201425          JR   FIN  4COP     0  US Citizen
# 2  25  201435-201445          JR  GBUS  4COP     0  US Citizen
# 3  37  201435-201445          SR  LGST  5COP     2  US Citizen
# 4  44  201435-201445          SO   BAE  5COP     1  US Citizen
#
#                                                 Acad  \
# 0                                               none
# 1  student needs a strong role model to help him ...
# 2  training or a course on corporate communicatio...
# 3                                               none
# 4                                               none
#
#                                               Acad_R
# 0                                                 []
# 1  [strong, role, model, focusing, career, goals,...
# 2  [training, corporate, communication, beneficia...
# ...

# %%
wnl = nltk.WordNetLemmatizer()
def WNlemmatization(s):
    text = [wnl.lemmatize(r) for r in s]
    return text
df0_1['lemm_A1']  = df0_1['Acad_R'].apply(lambda x: WNlemmatization(x))

# %%
df0_1.head()
# Out:
#    ID          Terms Class (BOT) Major  Conc  Coop Citizenship  \
# 0   6  201435-201445          SR  ACCT  4COP     0  US Citizen
# 1  11  201415-201425          JR   FIN  4COP     0  US Citizen
# 2  25  201435-201445          JR  GBUS  4COP     0  US Citizen
# 3  37  201435-201445          SR  LGST  5COP     2  US Citizen
# 4  44  201435-201445          SO   BAE  5COP     1  US Citizen
#
#                                                 Acad  \
# 0                                               none
# 1  student needs a strong role model to help him ...
# 2  training or a course on corporate communicatio...
# 3                                               none
# 4                                               none
#
#                                               Acad_R  \
# 0                                                 []
# 1  [strong, role, model, focusing, career, goals,...
# 2  [training, corporate, communication, beneficia...
# ...

# %%
df0_2 = df0_1.drop(['Acad'], axis=1)

# %%
df0_2.head()
# Out:
#    ID          Terms Class (BOT) Major  Conc  Coop Citizenship  \
# 0   6  201435-201445          SR  ACCT  4COP     0  US Citizen
# 1  11  201415-201425          JR   FIN  4COP     0  US Citizen
# 2  25  201435-201445          JR  GBUS  4COP     0  US Citizen
# 3  37  201435-201445          SR  LGST  5COP     2  US Citizen
# 4  44  201435-201445          SO   BAE  5COP     1  US Citizen
#
#                                               Acad_R  \
# 0                                                 []
# 1  [strong, role, model, focusing, career, goals,...
# 2  [training, corporate, communication, beneficia...
# 3                                                 []
# 4                                                 []
#
#                                              lemm_A1
# 0                                                 []
# 1  [strong, role, model, focusing, career, goal, ...
# 2  [training, corporate, communication, beneficia...
# ...

# %%
df0_2_A = df0_2.lemm_A1.sum()
print(df0_2_A)
# Out:
# ['strong', 'role', 'model', 'focusing', 'career', 'goal', 'finance', 'major', 'training', 'corporate', 'communication', 'beneficial', 'business', 'strategical', 'thinking', 'professional', 'field', 'technical', 'background', 'academic', 'experience', 'par', 'higher', 'peer', 'analyst', 'role', 'previous', 'related', 'subject', 'matter', 'posse', 'strong', 'mathematical', 'competency', 'problem', 'solving', 'academically', 'sufficient', 'enhancing', 'writingcommunication', 'discussed', 'addition', 'consider', 'continuing', 'gaining', 'knowledge', 'banking', 'compliance', 'rule', 'm', 'enjoy', 'try', 'get', 'experience', 'amlbsa', 'validation', 'tuning', 'possible', 'next', 'give', 'leg', 'next', 'year', 'accepts', 'another', 'internship', 'u', 'ask', 'employer', 'provide', 'standard', 'set', 'guideline', 'expectation', 'active', 'ing', 'employer', 'thing', 'startstop', 'time', 'punching', 'overtime', 'parameter', 'etc', 'encourage', 'accounting', 'prepare', 'field', 'emphasis', 'inter
# ...

# %%
import pandas as pd
import numpy as np 
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer 
from nltk import ngrams
from collections import Counter
import seaborn as sns
import matplotlib.pyplot as plt

# %%
bow_df0_2_A = Counter(df0_2_A)
bow_df0_2_A
# Out:
# Counter({'strong': 8,
#          'role': 11,
#          'model': 1,
#          'focusing': 2,
#          'career': 11,
#          'goal': 7,
#          'finance': 32,
#          'major': 9,
#          'training': 24,
#          'corporate': 5,
#          'communication': 31,
#          'beneficial': 6,
#          'business': 64,
#          'strategical': 1,
#          'thinking': 9,
#          'professional': 12,
#          'field': 13,
#          'technical': 7,
#          'background': 6,
#          'academic': 28,
#          'experience': 34,
#          'par': 1,
#          'higher': 3,
#          'peer': 3,
#          'analyst': 1,
#          'previous': 2,
#          'related': 8,
#          'subject': 1,
#          'matter': 1,
#          'posse': 1,
#          'mathematical': 1,
#          'competency': 1,
#          'problem': 12,
#          'solving': 8,
#          'academically': 4,
#          'sufficient': 3,
#          'enhancing': 2,
# ...

# %%
bow_df0_2_A1 = pd.DataFrame(bow_df0_2_A.items(),columns=['word','frequency']).sort_values(by='frequency',ascending=False)

# %%
bow_df0_2_A1
# Out:
#                word  frequency
# 12         business         64
# 97            excel         53
# 20       experience         34
# 6           finance         32
# 10    communication         31
# ...             ...        ...
# 778        finished          1
# 779          showed          1
# 217           visit          1
# 782       proactive          1
# 1283    statistical          1
#
# [1284 rows x 2 columns]

# %%
df0_Acad14 =bow_df0_2_A1.head(15) #15 is top15
print(df0_Acad14)
# Out:
#               word  frequency
# 12        business         64
# 97           excel         53
# 20      experience         34
# 6          finance         32
# 10   communication         31
# 19        academic         28
# 80      accounting         28
# 160        project         28
# 88       marketing         26
# 8         training         24
# 109        writing         24
# 74            time         24
# 143           take         23
# 274          think         23
# 127     management         23

# %%
sns.barplot(x='frequency',y='word',data=df0_Acad14)
# Out:
# <AxesSubplot:xlabel='frequency', ylabel='word'>

# %%
df0_Acad14_bi =Counter(ngrams(df0_2_A,2))
df0_Acad14_bi
# Out:
# Counter({('strong', 'role'): 1,
#          ('role', 'model'): 1,
#          ('model', 'focusing'): 1,
#          ('focusing', 'career'): 1,
#          ('career', 'goal'): 3,
#          ('goal', 'finance'): 1,
#          ('finance', 'major'): 2,
#          ('major', 'training'): 1,
#          ('training', 'corporate'): 1,
#          ('corporate', 'communication'): 1,
#          ('communication', 'beneficial'): 1,
#          ('beneficial', 'business'): 1,
#          ('business', 'strategical'): 1,
#          ('strategical', 'thinking'): 1,
#          ('thinking', 'professional'): 1,
#          ('professional', 'field'): 1,
#          ('field', 'technical'): 1,
#          ('technical', 'background'): 1,
#          ('background', 'academic'): 1,
#          ('academic', 'experience'): 2,
#          ('experience', 'par'): 1,
#          ('par', 'higher'): 1,
#          ('higher', 'peer'): 1,
#          ('peer', 'analyst'): 1,
#          ('analyst', 'role'): 1,
# ...

# %%
df0_Acad14_tri =Counter(ngrams(df0_2_A,3))
df0_Acad14_tri
# Out:
# Counter({('strong', 'role', 'model'): 1,
#          ('role', 'model', 'focusing'): 1,
#          ('model', 'focusing', 'career'): 1,
#          ('focusing', 'career', 'goal'): 1,
#          ('career', 'goal', 'finance'): 1,
#          ('goal', 'finance', 'major'): 1,
#          ('finance', 'major', 'training'): 1,
#          ('major', 'training', 'corporate'): 1,
#          ('training', 'corporate', 'communication'): 1,
#          ('corporate', 'communication', 'beneficial'): 1,
#          ('communication', 'beneficial', 'business'): 1,
#          ('beneficial', 'business', 'strategical'): 1,
#          ('business', 'strategical', 'thinking'): 1,
#          ('strategical', 'thinking', 'professional'): 1,
#          ('thinking', 'professional', 'field'): 1,
#          ('professional', 'field', 'technical'): 1,
#          ('field', 'technical', 'background'): 1,
#          ('technical', 'background', 'academic'): 1,
#          ('background', 'academic', 'experience'): 1,
# ...

# %%
df0_Acad14_tri1 = pd.DataFrame(df0_Acad14_tri.items(),columns=['word','frequency']).sort_values(by='frequency',ascending=False)

# %%
df0_Acad14_tri1.head(30)
# Out:
#                                         word  frequency
# 1812             (business, prior, starting)          2
# 958               (reasoning, taught, think)          2
# 521      (financial, managerial, accounting)          2
# 154         (finance, accounting, knowledge)          2
# 491                      (pivot, table, sum)          2
# 962   (organization, importantly, education)          2
# 961   (hindrance, organization, importantly)          2
# 960         (think, hindrance, organization)          2
# 959               (taught, think, hindrance)          2
# 957              (follow, reasoning, taught)          2
# 829                 (necessary, 150, credit)          2
# 956        (presentation, follow, reasoning)          2
# 955             (idea, presentation, follow)          2
# 954              (brief, idea, presentation)          2
# 953                      (give, brief, idea)          2
# 952                    (taught, give, brief)          2
# ...

# %%
df0_Acad14_bi1 = pd.DataFrame(df0_Acad14_bi.items(),columns=['word','frequency']).sort_values(by='frequency',ascending=False)

# %%
df0_Acad14_bi1.head(30)
# Out:
#                           word  frequency
# 664         (public, speaking)         14
# 34          (problem, solving)          8
# 264        (business, writing)          7
# 1434      (critical, thinking)          6
# 193        (microsoft, office)          6
# 2171         (excel, training)          6
# 196      (project, management)          6
# 146         (time, management)          5
# 231             (pivot, table)          5
# 2110     (accounting, finance)          4
# 1212          (social, medium)          4
# 925             (taught, give)          4
# 1584       (english, language)          4
# 1209          (quick, learner)          3
# 801      (expressed, interest)          3
# 904          (prepared, basic)          3
# 260         (microsoft, excel)          3
# 1531          (ability, speak)          3
# 1958     (financial, modeling)          3
# 877           (group, project)          3
# 918       (strength, weakness)          3
# ...

# %%
sns.barplot(x='frequency',y='word',data=df0_Acad14_tri1.head(30))
# Out:
# <AxesSubplot:xlabel='frequency', ylabel='word'>

# %%
sns.barplot(x='frequency',y='word',data=df0_Acad14_bi1.head(30))
# Out:
# <AxesSubplot:xlabel='frequency', ylabel='word'>

# %%
df1['Acad_R1'] = df1['Acad'].str.replace("students","")

# %%
df1['Acad_R1'] = df1['Acad_R1'].str.replace("student","")
df1['Acad_R1'] = df1['Acad_R1'].str.replace("course","")
df1['Acad_R1'] = df1['Acad_R1'].str.replace("college","")
df1['Acad_R1'] = df1['Acad_R1'].str.replace("coop","")
df1['Acad_R1'] = df1['Acad_R1'].str.replace("preparation","")
df1['Acad_R1'] = df1['Acad_R1'].str.replace("additional","")
df1['Acad_R1'] = df1['Acad_R1'].str.replace("better","")
df1['Acad_R1'] = df1['Acad_R1'].str.replace("understanding","")
df1['Acad_R1'] = df1['Acad_R1'].str.replace("continued","")
df1['Acad_R1'] = df1['Acad_R1'].str.replace("skill","")
df1['Acad_R1'] = df1['Acad_R1'].str.replace("believe","")
df1['Acad_R1'] = df1['Acad_R1'].str.replace("suggest","")
df1['Acad_R1'] = df1['Acad_R1'].str.replace("improvement","")
df1['Acad_R1'] = df1['Acad_R1'].str.replace("improve","")
df1['Acad_R1'] = df1['Acad_R1'].str.replace("incorporate","")
df1['Acad_R1'] = df1['Acad_R1'].str.replace("more","")
df1['Acad_R1'] = df1['Acad_R1'].str.replace("drexel","")
df1['Acad_R1'] = df1['Acad_R1'].str.replace("none","")
df1['Acad_R1'] = df1['Acad_R1'].str.replace("would","")
df1['Acad_R1'] = df1['Acad_R1'].str.replace("work","")
df1['Acad_R1'] = df1['Acad_R1'].str.replace("need","")
df1['Acad_R1'] = df1['Acad_R1'].str.replace("help","")
df1['Acad_R1'] = df1['Acad_R1'].str.replace("like","")
df1['Acad_R1'] = df1['Acad_R1'].str.replace("also","")
df1['Acad_R1'] = df1['Acad_R1'].str.replace("helpful","")
df1['Acad_R1'] = df1['Acad_R1'].str.replace("feel","")
df1['Acad_R1'] = df1['Acad_R1'].str.replace("continue","")
df1['Acad_R1'] = df1['Acad_R1'].str.replace("see","")
df1['Acad_R1'] = df1['Acad_R1'].str.replace("seemed","")
df1['Acad_R1'] = df1['Acad_R1'].str.replace("little","")
df1['Acad_R1'] = df1['Acad_R1'].str.replace("namely","")
df1['Acad_R1'] = df1['Acad_R1'].str.replace("doesnt","")
df1['Acad_R1'] = df1['Acad_R1'].str.replace("class","")
df1['Acad_R1'] = df1['Acad_R1'].str.replace("apply","")
df1['Acad_R1'] = df1['Acad_R1'].str.replace("ensure","")
df1['Acad_R1'] = df1['Acad_R1'].str.replace("either","")
df1['Acad_R1'] = df1['Acad_R1'].str.replace("already","")
df1['Acad_R1'] = df1['Acad_R1'].str.replace("use","")
df1['Acad_R1'] = df1['Acad_R1'].str.replace("well","")
df1['Acad_R1'] = df1['Acad_R1'].str.replace("take","")
df1['Acad_R1'] = df1['Acad_R1'].str.replace("help","")
df1['Acad_R1'] = df1['Acad_R1'].str.replace("think","")
df1['Acad_R1'] = df1['Acad_R1'].str.replace("could","")
df1['Acad_R1'] = df1['Acad_R1'].str.replace("coop","")
df1['Acad_R1'] = df1['Acad_R1'].str.replace("able","")
df1['Acad_R1'] = df1['Acad_R1'].str.replace("pick","")
df1['Acad_R1'] = df1['Acad_R1'].str.replace("beca","")
df1['Acad_R1'] = df1['Acad_R1'].str.replace("peter","")

# %%
df1_2 = df1.drop(['Strengths', 'Merged', 'Weakness'], axis=1)

# %%
df1_2.head()
# Out:
#    Responder ID          Terms Major  Conc Class                 Citizenship  \
# 0          2408  201535-201545   FIN  5COP    SR              Non US Citizen
# 1            63  201515-201525  ACCT  4COP    SR                  US Citizen
# 2            71  201515-201525   MIS  4COP    JR  Resident Alien Non-Citizen
# 3          2432  201535-201545   BAE  5COP    PJ                  US Citizen
# 4            78  201515-201525  ACCT  5COP    SR                  US Citizen
#
#    Coop                         Acad        Acad_R1
# 0     3  more accounting course work   accounting
# 1     0                         none
# 2     0                         none
# 3     2                         none
# 4     3                         none

# %%
# Printing lists of tokens (also known as lemmas) 
df1_2['Acad_R1'] = df1_2['Acad_R1'].apply(text_process)

# %%
df1_2.head()
# Out:
#    Responder ID          Terms Major  Conc Class                 Citizenship  \
# 0          2408  201535-201545   FIN  5COP    SR              Non US Citizen
# 1            63  201515-201525  ACCT  4COP    SR                  US Citizen
# 2            71  201515-201525   MIS  4COP    JR  Resident Alien Non-Citizen
# 3          2432  201535-201545   BAE  5COP    PJ                  US Citizen
# 4            78  201515-201525  ACCT  5COP    SR                  US Citizen
#
#    Coop                         Acad       Acad_R1
# 0     3  more accounting course work  [accounting]
# 1     0                         none            []
# 2     0                         none            []
# 3     2                         none            []
# 4     3                         none            []

# %%
wnl = nltk.WordNetLemmatizer()
def WNlemmatization(s):
    text = [wnl.lemmatize(r) for r in s]
    return text
df1_2['lemm_R']  = df1_2['Acad_R1'].apply(lambda x: WNlemmatization(x))

# %%
df1_2.head()
# Out:
#    Responder ID          Terms Major  Conc Class                 Citizenship  \
# 0          2408  201535-201545   FIN  5COP    SR              Non US Citizen
# 1            63  201515-201525  ACCT  4COP    SR                  US Citizen
# 2            71  201515-201525   MIS  4COP    JR  Resident Alien Non-Citizen
# 3          2432  201535-201545   BAE  5COP    PJ                  US Citizen
# 4            78  201515-201525  ACCT  5COP    SR                  US Citizen
#
#    Coop                         Acad       Acad_R1        lemm_R
# 0     3  more accounting course work  [accounting]  [accounting]
# 1     0                         none            []            []
# 2     0                         none            []            []
# 3     2                         none            []            []
# 4     3                         none            []            []

# %%
df1_2_A = df1_2.lemm_R.sum()
print(df1_2_A)
# Out:
# ['accounting', 'written', 'average', 'selecting', 'reflect', 'academic', 'date', 'paid', 'search', 'right', 'field', 'based', 'n', 'thus', 'far', 'overall', 'lack', 'growth', 'ability', 'make', 'general', 'connection', 'within', 'field', 'prior', 'starting', '6', 'month', 'sort', 'overview', 'general', 'direction', 'position', 'play', 'strength', 'interest', 'making', 'commitment', 'introductory', 'blueprint', 'reading', 'measure', 'drawing', 'quantity', 'offs', 'etc', 'beneficial', 'someone', 'want', 'company', 'canuso', 'jorden', 'knowing', 'finance', 'major', 'given', 'exposure', 'part', 'business', 'fault', 'unfortuntately', 'much', 'change', 'ethic', 'one', 'area', 'academic', 'might', 'ful', 'writing', 'particularly', 'business', 'environment', 'term', 'grammar', 'tone', 'darshils', 'email', 'communication', 'grammatically', 'incorrect', 'andor', 'casual', 'tone', 'place', 'found', 'many', 'careless', 'spelling', 'error', 'economics', 'finance', 'highly', 'beneficial', 'maybe',
# ...

# %%
bow_df1_2_A = Counter(df1_2_A)
bow_df1_2_A
# Out:
# Counter({'accounting': 25,
#          'written': 3,
#          'average': 2,
#          'selecting': 1,
#          'reflect': 1,
#          'academic': 24,
#          'date': 3,
#          'paid': 1,
#          'search': 1,
#          'right': 5,
#          'field': 10,
#          'based': 5,
#          'n': 6,
#          'thus': 1,
#          'far': 2,
#          'overall': 3,
#          'lack': 2,
#          'growth': 2,
#          'ability': 5,
#          'make': 11,
#          'general': 9,
#          'connection': 3,
#          'within': 5,
#          'prior': 3,
#          'starting': 1,
#          '6': 1,
#          'month': 3,
#          'sort': 1,
#          'overview': 2,
#          'direction': 5,
#          'position': 12,
#          'play': 1,
#          'strength': 2,
#          'interest': 8,
#          'making': 2,
#          'commitment': 3,
#          'introductory': 1,
#          'blueprint': 1,
#          'reading': 2,
#          'measure': 1,
# ...

# %%
bow_df1_2_A1 = pd.DataFrame(bow_df1_2_A.items(),columns=['word','frequency']).sort_values(by='frequency',ascending=False)

# %%
bow_df1_2_A1.head(30)
# Out:
#               word  frequency
# 56        business         46
# 93               e         38
# 239          excel         37
# 151      marketing         27
# 0       accounting         25
# 5         academic         24
# 74   communication         24
# 66         writing         23
# 139           task         22
# 162           time         21
# 130     experience         18
# 204       prepared         18
# 187          basic         16
# 65             ful         16
# 54        exposure         15
# 242          focus         15
# 286             ed         15
# 88        training         15
# 222   professional         15
# 153       learning         14
# 457           role         14
# 336          learn         14
# 306     management         14
# 217           good         14
# 63            area         14
# 257            job         14
# 113         office         13
# 51         finance         13
# 128   presentation         12
# 73           email         12

# %%
df1_Acad15 =bow_df1_2_A1.head(20) #20 is top20
print(df1_Acad15)
# Out:
#               word  frequency
# 56        business         46
# 93               e         38
# 239          excel         37
# 151      marketing         27
# 0       accounting         25
# 5         academic         24
# 74   communication         24
# 66         writing         23
# 139           task         22
# 162           time         21
# 130     experience         18
# 204       prepared         18
# 187          basic         16
# 65             ful         16
# 54        exposure         15
# 242          focus         15
# 286             ed         15
# 88        training         15
# 222   professional         15
# 153       learning         14

# %%
sns.barplot(x='frequency',y='word',data=df1_Acad15)
# Out:
# <AxesSubplot:xlabel='frequency', ylabel='word'>

# %%
df1_Acad15_bi =Counter(ngrams(df1_2_A,2))
df1_Acad15_bi
# Out:
# Counter({('accounting', 'written'): 1,
#          ('written', 'average'): 1,
#          ('average', 'selecting'): 1,
#          ('selecting', 'reflect'): 1,
#          ('reflect', 'academic'): 1,
#          ('academic', 'date'): 1,
#          ('date', 'paid'): 1,
#          ('paid', 'search'): 1,
#          ('search', 'right'): 1,
#          ('right', 'field'): 1,
#          ('field', 'based'): 1,
#          ('based', 'n'): 1,
#          ('n', 'thus'): 1,
#          ('thus', 'far'): 1,
#          ('far', 'overall'): 1,
#          ('overall', 'lack'): 1,
#          ('lack', 'growth'): 1,
#          ('growth', 'ability'): 1,
#          ('ability', 'make'): 1,
#          ('make', 'general'): 1,
#          ('general', 'connection'): 1,
#          ('connection', 'within'): 1,
#          ('within', 'field'): 1,
#          ('field', 'prior'): 1,
#          ('prior', 'starting'): 1,
#          ('starting', '6'): 1,
#          ('6', 'month'): 1,
#          ('month', 'sort'): 1,
# ...

# %%
df1_Acad15_tri =Counter(ngrams(df1_2_A,3))
df1_Acad15_tri
# Out:
# Counter({('accounting', 'written', 'average'): 1,
#          ('written', 'average', 'selecting'): 1,
#          ('average', 'selecting', 'reflect'): 1,
#          ('selecting', 'reflect', 'academic'): 1,
#          ('reflect', 'academic', 'date'): 1,
#          ('academic', 'date', 'paid'): 1,
#          ('date', 'paid', 'search'): 1,
#          ('paid', 'search', 'right'): 1,
#          ('search', 'right', 'field'): 1,
#          ('right', 'field', 'based'): 1,
#          ('field', 'based', 'n'): 1,
#          ('based', 'n', 'thus'): 1,
#          ('n', 'thus', 'far'): 1,
#          ('thus', 'far', 'overall'): 1,
#          ('far', 'overall', 'lack'): 1,
#          ('overall', 'lack', 'growth'): 1,
#          ('lack', 'growth', 'ability'): 1,
#          ('growth', 'ability', 'make'): 1,
#          ('ability', 'make', 'general'): 1,
#          ('make', 'general', 'connection'): 1,
#          ('general', 'connection', 'within'): 1,
#          ('connection', 'within', 'field'): 1,
# ...

# %%
df1_Acad15_tri1 = pd.DataFrame(df1_Acad15_tri.items(),columns=['word','frequency']).sort_values(by='frequency',ascending=False)

# %%
df1_Acad15_tri1.head(30)
# Out:
#                                           word  frequency
# 308                      (e, public, speaking)          3
# 436                           (sit, cpa, exam)          3
# 596         (encompasses, business, etiquette)          2
# 660                  (experience, office, 101)          2
# 778               (however, understand, offer)          2
# 779                  (understand, offer, path)          2
# 780                      (offer, path, toward)          2
# 781                     (path, toward, credit)          2
# 782                (toward, credit, threshold)          2
# 2328                (accounting, major, great)          2
# 663                 (email, etiquette, social)          2
# 662                    (101, email, etiquette)          2
# 661                       (office, 101, email)          2
# 659                  (ful, experience, office)          2
# 411     (accountingauditing, load, beneficial)          2
# ...

# %%
df0_Acad14_bi1 = pd.DataFrame(df0_Acad14_bi.items(),columns=['word','frequency']).sort_values(by='frequency',ascending=False)

# %%
df0_Acad14_bi1.head(30)
# Out:
#                           word  frequency
# 664         (public, speaking)         14
# 34          (problem, solving)          8
# 264        (business, writing)          7
# 1434      (critical, thinking)          6
# 193        (microsoft, office)          6
# 2171         (excel, training)          6
# 196      (project, management)          6
# 146         (time, management)          5
# 231             (pivot, table)          5
# 2110     (accounting, finance)          4
# 1212          (social, medium)          4
# 925             (taught, give)          4
# 1584       (english, language)          4
# 1209          (quick, learner)          3
# 801      (expressed, interest)          3
# 904          (prepared, basic)          3
# 260         (microsoft, excel)          3
# 1531          (ability, speak)          3
# 1958     (financial, modeling)          3
# 877           (group, project)          3
# 918       (strength, weakness)          3
# ...

# %%
sns.barplot(x='frequency',y='word',data=df1_Acad15_tri1.head(30))
# Out:
# <AxesSubplot:xlabel='frequency', ylabel='word'>

# %%
df1_Acad15_bi1 = pd.DataFrame(df1_Acad15_bi.items(),columns=['word','frequency']).sort_values(by='frequency',ascending=False)

# %%
df1_Acad15_bi1.head(30)
# Out:
#                            word  frequency
# 307          (public, speaking)          7
# 660            (social, medium)          6
# 521         (excel, powerpoint)          5
# 141          (problem, solving)          5
# 762          (pursuing, career)          4
# 350          (microsoft, excel)          4
# 586           (advanced, excel)          4
# 598     (professional, writing)          3
# 1028         (business, acumen)          3
# 1794                   (co, op)          3
# 820         (business, writing)          3
# 122     (verbal, communication)          3
# 855   (business, communication)          3
# 434                  (sit, cpa)          3
# 435                 (cpa, exam)          3
# 859               (real, world)          3
# 1025      (project, management)          3
# 1027       (exposure, business)          3
# 453                (learn, new)          3
# 71      (business, environment)          3
# 599            (writing, email)          3
# ...

# %%
sns.barplot(x='frequency',y='word',data=df1_Acad15_bi1.head(30))
# Out:
# <AxesSubplot:xlabel='frequency', ylabel='word'>

# %%
df2['Acad_R1'] = df2['Acad'].str.replace("students","")

# %%
df2.head()
# Out:
#    Responder ID     Work Terms Major  Conc Class Citizenship  Coop  \
# 0            98  201615-201625   FIN  5COP    SR  US Citizen     3
# 1           105  201615-201625  ACCT  5COP    SR  US Citizen     3
# 2           148  201615-201625  GBUS  5COP    JR  US Citizen     3
# 3           159  201615-201625   FIN  5COP    SR  US Citizen     3
# 4           181  201615-201625  MKTG  5COP    JR  US Citizen     3
#
#                                            Strengths  \
# 0  Michael was enthusiastic in his responsibiliti...
# 1  Andrew added a lot of value to PCM during his ...
# 2  Nick got along well with other co-ops and was ...
# 3  Dave is an incredibly hard worker, and stays m...
# 4  Lauren has a fantastic ability to take what sh...
#
#                                             Weakness  \
# 0  He was honest in his assessment that this is n...
# 1  Andrew can continue to grow and improve his wr...
# 2  Nick showed little initiative to learn or grow...
# ...

# %%
df2['Acad_R1'] = df2['Acad_R1'].str.replace("student","")
df2['Acad_R1'] = df2['Acad_R1'].str.replace("course","")
df2['Acad_R1'] = df2['Acad_R1'].str.replace("college","")
df2['Acad_R1'] = df2['Acad_R1'].str.replace("coop","")
df2['Acad_R1'] = df2['Acad_R1'].str.replace("preparation","")
df2['Acad_R1'] = df2['Acad_R1'].str.replace("additional","")
df2['Acad_R1'] = df2['Acad_R1'].str.replace("better","")
df2['Acad_R1'] = df2['Acad_R1'].str.replace("understanding","")
df2['Acad_R1'] = df2['Acad_R1'].str.replace("continued","")
df2['Acad_R1'] = df2['Acad_R1'].str.replace("skill","")
df2['Acad_R1'] = df2['Acad_R1'].str.replace("believe","")
df2['Acad_R1'] = df2['Acad_R1'].str.replace("suggest","")
df2['Acad_R1'] = df2['Acad_R1'].str.replace("improvement","")
df2['Acad_R1'] = df2['Acad_R1'].str.replace("improve","")
df2['Acad_R1'] = df2['Acad_R1'].str.replace("incorporate","")
df2['Acad_R1'] = df2['Acad_R1'].str.replace("more","")
df2['Acad_R1'] = df2['Acad_R1'].str.replace("drexel","")
df2['Acad_R1'] = df2['Acad_R1'].str.replace("none","")
df2['Acad_R1'] = df2['Acad_R1'].str.replace("would","")
df2['Acad_R1'] = df2['Acad_R1'].str.replace("work","")
df2['Acad_R1'] = df2['Acad_R1'].str.replace("need","")
df2['Acad_R1'] = df2['Acad_R1'].str.replace("help","")
df2['Acad_R1'] = df2['Acad_R1'].str.replace("like","")
df2['Acad_R1'] = df2['Acad_R1'].str.replace("also","")
df2['Acad_R1'] = df2['Acad_R1'].str.replace("helpful","")
df2['Acad_R1'] = df2['Acad_R1'].str.replace("feel","")
df2['Acad_R1'] = df2['Acad_R1'].str.replace("continue","")
df2['Acad_R1'] = df2['Acad_R1'].str.replace("see","")
df2['Acad_R1'] = df2['Acad_R1'].str.replace("seemed","")
df2['Acad_R1'] = df2['Acad_R1'].str.replace("little","")
df2['Acad_R1'] = df2['Acad_R1'].str.replace("namely","")
df2['Acad_R1'] = df2['Acad_R1'].str.replace("doesnt","")
df2['Acad_R1'] = df2['Acad_R1'].str.replace("class","")
df2['Acad_R1'] = df2['Acad_R1'].str.replace("apply","")
df2['Acad_R1'] = df2['Acad_R1'].str.replace("ensure","")
df2['Acad_R1'] = df2['Acad_R1'].str.replace("either","")
df2['Acad_R1'] = df2['Acad_R1'].str.replace("already","")
df2['Acad_R1'] = df2['Acad_R1'].str.replace("use","")
df2['Acad_R1'] = df2['Acad_R1'].str.replace("well","")
df2['Acad_R1'] = df2['Acad_R1'].str.replace("take","")
df2['Acad_R1'] = df2['Acad_R1'].str.replace("help","")
df2['Acad_R1'] = df2['Acad_R1'].str.replace("think","")
df2['Acad_R1'] = df2['Acad_R1'].str.replace("could","")
df2['Acad_R1'] = df2['Acad_R1'].str.replace("able","")
df2['Acad_R1'] = df2['Acad_R1'].str.replace("pick","")
df2['Acad_R1'] = df2['Acad_R1'].str.replace("peter","")
df2['Acad_R1'] = df2['Acad_R1'].str.replace("andrew","")

# %%
df2_1 = df2.drop(['Strengths', 'Weakness', 'Merged'], axis=1)

# %%
df2_1.head()
# Out:
#    Responder ID     Work Terms Major  Conc Class Citizenship  Coop  \
# 0            98  201615-201625   FIN  5COP    SR  US Citizen     3
# 1           105  201615-201625  ACCT  5COP    SR  US Citizen     3
# 2           148  201615-201625  GBUS  5COP    JR  US Citizen     3
# 3           159  201615-201625   FIN  5COP    SR  US Citizen     3
# 4           181  201615-201625  MKTG  5COP    JR  US Citizen     3
#
#                                                 Acad  \
# 0               more math and accounting course work
# 1  andrew had a great foundation from his classwo...
# 2  i dont think any poor performance is due to la...
# 3                                               none
# 4                                               none
#
#                                              Acad_R1
# 0                              math and accounting
# 1   had a great foundation from his  for this    ...
# 2  i dont  any poor performance is due to lack of...
# 3
# 4

# %%
# Printing lists of tokens (also known as lemmas) 
df2_1['Acad_R1'] = df2_1['Acad_R1'].apply(text_process)

# %%
df2_1.head()
# Out:
#    Responder ID     Work Terms Major  Conc Class Citizenship  Coop  \
# 0            98  201615-201625   FIN  5COP    SR  US Citizen     3
# 1           105  201615-201625  ACCT  5COP    SR  US Citizen     3
# 2           148  201615-201625  GBUS  5COP    JR  US Citizen     3
# 3           159  201615-201625   FIN  5COP    SR  US Citizen     3
# 4           181  201615-201625  MKTG  5COP    JR  US Citizen     3
#
#                                                 Acad  \
# 0               more math and accounting course work
# 1  andrew had a great foundation from his classwo...
# 2  i dont think any poor performance is due to la...
# 3                                               none
# 4                                               none
#
#                                              Acad_R1
# 0                                 [math, accounting]
# 1  [great, foundation, es, financial, planning, ful]
# 2     [dont, poor, performance, due, lack, academic]
# ...

# %%
wnl = nltk.WordNetLemmatizer()
def WNlemmatization(s):
    text = [wnl.lemmatize(r) for r in s]
    return text
df2_1['lemm_A1']  = df2_1['Acad_R1'].apply(lambda x: WNlemmatization(x))

# %%
df2_1.head()
# Out:
#    Responder ID     Work Terms Major  Conc Class Citizenship  Coop  \
# 0            98  201615-201625   FIN  5COP    SR  US Citizen     3
# 1           105  201615-201625  ACCT  5COP    SR  US Citizen     3
# 2           148  201615-201625  GBUS  5COP    JR  US Citizen     3
# 3           159  201615-201625   FIN  5COP    SR  US Citizen     3
# 4           181  201615-201625  MKTG  5COP    JR  US Citizen     3
#
#                                                 Acad  \
# 0               more math and accounting course work
# 1  andrew had a great foundation from his classwo...
# 2  i dont think any poor performance is due to la...
# 3                                               none
# 4                                               none
#
#                                              Acad_R1  \
# 0                                 [math, accounting]
# 1  [great, foundation, es, financial, planning, ful]
# 2     [dont, poor, performance, due, lack, academic]
# ...

# %%
df2_2_A = df2_1.lemm_A1.sum()
print(df2_2_A)
# Out:
# ['math', 'accounting', 'great', 'foundation', 'e', 'financial', 'planning', 'ful', 'dont', 'poor', 'performance', 'due', 'lack', 'academic', 'basic', 'ing', 'knowledge', 'risk', 'management', 'concept', 'coupled', 'finance', 'background', 'serve', 'participant', 'position', 'however', 'dayonoh', 'grear', 'exhibited', 'finance', 'background', 'without', 'practical', 'risk', 'management', 'experience', 'suffice', 'certain', 'participant', 'cap', 'willing', 'learn', 'fly', 'activity', 'allow', 'develop', 'capability', 'connecting', 'big', 'picture', 'selfdirected', 'teasing', 'important', 'aspect', 'business', 'situation', 'connduct', 'thorough', 'market', 'analysis', 'develop', 'excel', 'even', 'efficient', 'accounting', 'engage', 'neting', 'activity', 'provided', 'attendance', 'issue', 'impactful', 'self', 'motivated', 'aggressive', 'energetic', 'toward', 'acheiving', 'goal', 'alum', 'excel', 'basic', 'taught', 'immediately', 'regardless', 'rachael', 'learned', 'fast', 'robbie', 'came
# ...

# %%
bow_df2_2_A = Counter(df2_2_A)
bow_df2_2_A
# Out:
# Counter({'math': 3,
#          'accounting': 22,
#          'great': 9,
#          'foundation': 2,
#          'e': 20,
#          'financial': 5,
#          'planning': 3,
#          'ful': 13,
#          'dont': 2,
#          'poor': 1,
#          'performance': 1,
#          'due': 2,
#          'lack': 1,
#          'academic': 28,
#          'basic': 7,
#          'ing': 18,
#          'knowledge': 12,
#          'risk': 2,
#          'management': 22,
#          'concept': 8,
#          'coupled': 1,
#          'finance': 16,
#          'background': 13,
#          'serve': 2,
#          'participant': 2,
#          'position': 14,
#          'however': 5,
#          'dayonoh': 1,
#          'grear': 1,
#          'exhibited': 1,
#          'without': 1,
#          'practical': 1,
#          'experience': 19,
#          'suffice': 1,
#          'certain': 3,
#          'cap': 1,
#          'willing': 1,
#          'learn': 10,
#          'fly': 1,
#          'activity': 3,
# ...

# %%
bow_df2_2_A1 = pd.DataFrame(bow_df2_2_A.items(),columns=['word','frequency']).sort_values(by='frequency',ascending=False)

# %%
bow_df2_2_A1.head(30)
# Out:
#               word  frequency
# 50        business         39
# 13        academic         28
# 56           excel         28
# 1       accounting         22
# 18      management         22
# 100          focus         21
# 160       prepared         21
# 4                e         20
# 98       marketing         19
# 32      experience         19
# 123           time         19
# 15             ing         18
# 211        project         16
# 21         finance         16
# 459        program         15
# 266           role         15
# 25        position         14
# 22      background         13
# 201       training         13
# 7              ful         13
# 335        company         13
# 170  communication         13
# 214           data         13
# 77         learned         12
# 16       knowledge         12
# 316         future         11
# 151           task         11
# 109           team         11
# 139            etc         11
# 156    opportunity         10

# %%
df2_Acad16 =bow_df2_2_A1.head(15) #15 is top15
print(df2_Acad16)
# Out:
#            word  frequency
# 50     business         39
# 13     academic         28
# 56        excel         28
# 1    accounting         22
# 18   management         22
# 100       focus         21
# 160    prepared         21
# 4             e         20
# 98    marketing         19
# 32   experience         19
# 123        time         19
# 15          ing         18
# 211     project         16
# 21      finance         16
# 459     program         15

# %%
sns.barplot(x='frequency',y='word',data=df2_Acad16)
# Out:
# <AxesSubplot:xlabel='frequency', ylabel='word'>

# %%
df2_Acad16_bi =Counter(ngrams(df2_2_A,2))
df2_Acad16_bi
# Out:
# Counter({('math', 'accounting'): 3,
#          ('accounting', 'great'): 1,
#          ('great', 'foundation'): 1,
#          ('foundation', 'e'): 1,
#          ('e', 'financial'): 1,
#          ('financial', 'planning'): 1,
#          ('planning', 'ful'): 1,
#          ('ful', 'dont'): 1,
#          ('dont', 'poor'): 1,
#          ('poor', 'performance'): 1,
#          ('performance', 'due'): 1,
#          ('due', 'lack'): 1,
#          ('lack', 'academic'): 1,
#          ('academic', 'basic'): 1,
#          ('basic', 'ing'): 1,
#          ('ing', 'knowledge'): 2,
#          ('knowledge', 'risk'): 1,
#          ('risk', 'management'): 2,
#          ('management', 'concept'): 1,
#          ('concept', 'coupled'): 1,
#          ('coupled', 'finance'): 1,
#          ('finance', 'background'): 2,
#          ('background', 'serve'): 1,
#          ('serve', 'participant'): 1,
#          ('participant', 'position'): 1,
#          ('position', 'however'): 2,
# ...

# %%
df2_Acad16_tri =Counter(ngrams(df2_2_A,3))
df2_Acad16_tri
# Out:
# Counter({('math', 'accounting', 'great'): 1,
#          ('accounting', 'great', 'foundation'): 1,
#          ('great', 'foundation', 'e'): 1,
#          ('foundation', 'e', 'financial'): 1,
#          ('e', 'financial', 'planning'): 1,
#          ('financial', 'planning', 'ful'): 1,
#          ('planning', 'ful', 'dont'): 1,
#          ('ful', 'dont', 'poor'): 1,
#          ('dont', 'poor', 'performance'): 1,
#          ('poor', 'performance', 'due'): 1,
#          ('performance', 'due', 'lack'): 1,
#          ('due', 'lack', 'academic'): 1,
#          ('lack', 'academic', 'basic'): 1,
#          ('academic', 'basic', 'ing'): 1,
#          ('basic', 'ing', 'knowledge'): 1,
#          ('ing', 'knowledge', 'risk'): 1,
#          ('knowledge', 'risk', 'management'): 1,
#          ('risk', 'management', 'concept'): 1,
#          ('management', 'concept', 'coupled'): 1,
#          ('concept', 'coupled', 'finance'): 1,
#          ('coupled', 'finance', 'background'): 1,
# ...

# %%
df2_Acad16_tri1 = pd.DataFrame(df2_Acad16_tri.items(),columns=['word','frequency']).sort_values(by='frequency',ascending=False)

# %%
df2_Acad16_bi1 = pd.DataFrame(df2_Acad16_bi.items(),columns=['word','frequency']).sort_values(by='frequency',ascending=False)

# %%
df2_Acad16_tri1.head(30)
# Out:
#                                           word  frequency
# 744        (university, provides, fundamental)          3
# 740                   (program, prepare, role)          3
# 746        (fundamental, business, background)          3
# 745          (provides, fundamental, business)          3
# 743         (department, university, provides)          3
# 742             (role, department, university)          3
# 741                (prepare, role, department)          3
# 739               (academic, program, prepare)          3
# 738             (necessary, academic, program)          3
# 737              (change, necessary, academic)          3
# 736                (observ, change, necessary)          3
# 661                   (exchange, traded, fund)          3
# 972           (exposure, valuation, technique)          2
# 311               (product, benefit, business)          2
# 309            (exposure, investment, product)          2
# ...

# %%
df2_Acad16_bi1.head(30)
# Out:
#                           word  frequency
# 167         (time, management)          8
# 226       (prepared, position)          6
# 221            (critical, ing)          6
# 1288        (public, speaking)          5
# 390      (project, management)          5
# 1203          (small, company)          5
# 734     (business, background)          4
# 1327     (business, analytics)          4
# 1292        (pursuing, career)          3
# 1824          (prepared, role)          3
# 733    (fundamental, business)          3
# 320         (business, acumen)          3
# 732    (provides, fundamental)          3
# 651             (traded, fund)          3
# 731     (university, provides)          3
# 730   (department, university)          3
# 565        (microsoft, office)          3
# 729         (role, department)          3
# 728            (prepare, role)          3
# 727         (program, prepare)          3
# 47              (big, picture)          3
# ...

# %%
sns.barplot(x='frequency',y='word',data=df2_Acad16_tri1.head(30))
# Out:
# <AxesSubplot:xlabel='frequency', ylabel='word'>

# %%
sns.barplot(x='frequency',y='word',data=df2_Acad16_bi1.head(30))
# Out:
# <AxesSubplot:xlabel='frequency', ylabel='word'>

# %%
df2_Acad16_bi1.head(30)
# Out:
#                           word  frequency
# 167         (time, management)          8
# 226       (prepared, position)          6
# 221            (critical, ing)          6
# 1288        (public, speaking)          5
# 390      (project, management)          5
# 1203          (small, company)          5
# 734     (business, background)          4
# 1327     (business, analytics)          4
# 1292        (pursuing, career)          3
# 1824          (prepared, role)          3
# 733    (fundamental, business)          3
# 320         (business, acumen)          3
# 732    (provides, fundamental)          3
# 651             (traded, fund)          3
# 731     (university, provides)          3
# 730   (department, university)          3
# 565        (microsoft, office)          3
# 729         (role, department)          3
# 728            (prepare, role)          3
# 727         (program, prepare)          3
# 47              (big, picture)          3
# ...

# %%
df3['Acad_R1'] = df3['Acad'].str.replace("students","")

# %%
df3.head()
# Out:
#    Responder ID     Work Terms Major Concentration Class Citizenship   Coop  \
# 0           391  201715-201725   FIN          5COP    SO   US Citizen     1
# 1          1465  201715-201725   FIN          5COP    JR   US Citizen     3
# 2          1476  201715-201725  OSCM          5COP    JR   US Citizen     3
# 3           393  201715-201725  LGST          4COP    PJ   US Citizen     0
# 4          1484  201715-201725  MKTG          5COP    SR   US Citizen     3
#
#                                            Strengths  \
# 0  Over the course of Sachin's co-op he demonstra...
# 1  Steve is very dependable and was able to work ...
# 2  Taniya has been a great asset to the team. She...
# 3  mature, pleasant interaction with FAIMER staff...
# 4            Great attitude and willingness to learn
#
#                                             Weakness  \
# 0  Sachin struggled with multi-tasking and time m...
# 1  Steve is young but he should not be afraid of ...
# ...

# %%
df3['Acad_R1'] = df3['Acad_R1'].str.replace("student","")
df3['Acad_R1'] = df3['Acad_R1'].str.replace("course","")
df3['Acad_R1'] = df3['Acad_R1'].str.replace("college","")
df3['Acad_R1'] = df3['Acad_R1'].str.replace("coop","")
df3['Acad_R1'] = df3['Acad_R1'].str.replace("preparation","")
df3['Acad_R1'] = df3['Acad_R1'].str.replace("additional","")
df3['Acad_R1'] = df3['Acad_R1'].str.replace("better","")
df3['Acad_R1'] = df3['Acad_R1'].str.replace("understanding","")
df3['Acad_R1'] = df3['Acad_R1'].str.replace("continued","")
df3['Acad_R1'] = df3['Acad_R1'].str.replace("skill","")
df3['Acad_R1'] = df3['Acad_R1'].str.replace("believe","")
df3['Acad_R1'] = df3['Acad_R1'].str.replace("suggest","")
df3['Acad_R1'] = df3['Acad_R1'].str.replace("improvement","")
df3['Acad_R1'] = df3['Acad_R1'].str.replace("improve","")
df3['Acad_R1'] = df3['Acad_R1'].str.replace("incorporate","")
df3['Acad_R1'] = df3['Acad_R1'].str.replace("more","")
df3['Acad_R1'] = df3['Acad_R1'].str.replace("drexel","")
df3['Acad_R1'] = df3['Acad_R1'].str.replace("none","")
df3['Acad_R1'] = df3['Acad_R1'].str.replace("would","")
df3['Acad_R1'] = df3['Acad_R1'].str.replace("work","")
df3['Acad_R1'] = df3['Acad_R1'].str.replace("need","")
df3['Acad_R1'] = df3['Acad_R1'].str.replace("help","")
df3['Acad_R1'] = df3['Acad_R1'].str.replace("like","")
df3['Acad_R1'] = df3['Acad_R1'].str.replace("also","")
df3['Acad_R1'] = df3['Acad_R1'].str.replace("helpful","")
df3['Acad_R1'] = df3['Acad_R1'].str.replace("feel","")
df3['Acad_R1'] = df3['Acad_R1'].str.replace("continue","")
df3['Acad_R1'] = df3['Acad_R1'].str.replace("see","")
df3['Acad_R1'] = df3['Acad_R1'].str.replace("seemed","")
df3['Acad_R1'] = df3['Acad_R1'].str.replace("little","")
df3['Acad_R1'] = df3['Acad_R1'].str.replace("namely","")
df3['Acad_R1'] = df3['Acad_R1'].str.replace("doesnt","")
df3['Acad_R1'] = df3['Acad_R1'].str.replace("class","")
df3['Acad_R1'] = df3['Acad_R1'].str.replace("apply","")
df3['Acad_R1'] = df3['Acad_R1'].str.replace("ensure","")
df3['Acad_R1'] = df3['Acad_R1'].str.replace("either","")
df3['Acad_R1'] = df3['Acad_R1'].str.replace("already","")
df3['Acad_R1'] = df3['Acad_R1'].str.replace("use","")
df3['Acad_R1'] = df3['Acad_R1'].str.replace("well","")
df3['Acad_R1'] = df3['Acad_R1'].str.replace("take","")
df3['Acad_R1'] = df3['Acad_R1'].str.replace("help","")
df3['Acad_R1'] = df3['Acad_R1'].str.replace("think","")
df3['Acad_R1'] = df3['Acad_R1'].str.replace("could","")
df3['Acad_R1'] = df3['Acad_R1'].str.replace("able","")
df3['Acad_R1'] = df3['Acad_R1'].str.replace("pick","")
df3['Acad_R1'] = df3['Acad_R1'].str.replace("peter","")
df3['Acad_R1'] = df3['Acad_R1'].str.replace("andrew","")

# %%
df3_1 = df3.drop(['Strengths', 'Weakness', 'Merged'], axis=1)

# %%
# Printing lists of tokens (also known as lemmas) 
df3_1['Acad_R1'] = df3_1['Acad_R1'].apply(text_process)

# %%
wnl = nltk.WordNetLemmatizer()
def WNlemmatization(s):
    text = [wnl.lemmatize(r) for r in s]
    return text
df3_1['lemm_A1']  = df3_1['Acad_R1'].apply(lambda x: WNlemmatization(x))

# %%
df3_1.head()
# Out:
#    Responder ID     Work Terms Major Concentration Class Citizenship   Coop  \
# 0           391  201715-201725   FIN          5COP    SO   US Citizen     1
# 1          1465  201715-201725   FIN          5COP    JR   US Citizen     3
# 2          1476  201715-201725  OSCM          5COP    JR   US Citizen     3
# 3           393  201715-201725  LGST          4COP    PJ   US Citizen     0
# 4          1484  201715-201725  MKTG          5COP    SR   US Citizen     3
#
#                                                 Acad  \
# 0  his performance was relatively staticwe did no...
# 1                                               none
# 2                                               none
# 3                                               none
# 4                                               none
#
#                                              Acad_R1  \
# 0  [performance, relatively, staticwe, much, grow...
# 1                                                 []
# ...

# %%
df3_2_A = df3_1.lemm_A1.sum()
print(df3_2_A)
# Out:
# ['performance', 'relatively', 'staticwe', 'much', 'growth', 'responsibility', 'time', 'however', 'thats', 'due', 'large', 'part', 'fact', 'first', 'never', 'experience', 'fastpaced', 'corporate', 'environment', 'expect', 'experience', 'sachins', 'overall', 'excel', 'business', 'intelligence', 'tool', 'tau', 'cognos', 'qlikview', 'maybe', 'emphasis', 'supply', 'chain', 'relates', 'corporate', 'world', 'rachael', 'grow', 'professionalism', 'regard', 'communication', 'via', 'email', 'text', 'im', 'professional', 'appearance', 'ethic', 'rachael', 'never', 'showed', 'initiative', 'asked', 'project', 'go', 'long', 'way', 'reviewing', 'completing', 'step', 'project', 'submitting', 'prompted', 'submit', 'area', 'succeed', 'ing', 'world', 'katie', 'valu', 'member', 'team', 'happy', 'back', 'second', 'term', 'business', 'look', 'latest', 'trend', 'futurist', 'informed', 'prior', 'coming', 'force', 'thing', 'talked', 'next', 'gen', 'asked', 'contribute', 'hunter', 'suited', 'learning', 'real', 
# ...

# %%
bow_df3_2_A = Counter(df3_2_A)
bow_df3_2_A
# Out:
# Counter({'performance': 3,
#          'relatively': 1,
#          'staticwe': 1,
#          'much': 3,
#          'growth': 4,
#          'responsibility': 4,
#          'time': 22,
#          'however': 4,
#          'thats': 3,
#          'due': 3,
#          'large': 2,
#          'part': 3,
#          'fact': 1,
#          'first': 8,
#          'never': 2,
#          'experience': 37,
#          'fastpaced': 1,
#          'corporate': 6,
#          'environment': 13,
#          'expect': 3,
#          'sachins': 1,
#          'overall': 5,
#          'excel': 34,
#          'business': 36,
#          'intelligence': 1,
#          'tool': 8,
#          'tau': 2,
#          'cognos': 1,
#          'qlikview': 1,
#          'maybe': 2,
#          'emphasis': 2,
#          'supply': 2,
#          'chain': 2,
#          'relates': 2,
#          'world': 5,
#          'rachael': 2,
#          'grow': 3,
#          'professionalism': 3,
#          'regard': 2,
# ...

# %%
bow_df3_2_A1 = pd.DataFrame(bow_df3_2_A.items(),columns=['word','frequency']).sort_values(by='frequency',ascending=False)

# %%
bow_df3_2_A1.head(30)
# Out:
#               word  frequency
# 15      experience         37
# 23        business         36
# 22           excel         34
# 106              e         33
# 96        academic         31
# 109     accounting         31
# 125      knowledge         30
# 158       prepared         27
# 66            team         25
# 39   communication         24
# 94         finance         24
# 137          learn         23
# 6             time         22
# 255        writing         21
# 50         project         19
# 44    professional         18
# 325     management         18
# 262           data         18
# 115           role         18
# 184         career         18
# 129     understand         16
# 180            ful         16
# 210          major         15
# 62             ing         15
# 99        position         15
# 365          basic         15
# 203      financial         14
# 208          focus         14
# 338       analysis         14
# 230        benefit         14

# %%
df3_Acad17 =bow_df3_2_A1.head(15) #15 is top15
print(df3_Acad17)
# Out:
#               word  frequency
# 15      experience         37
# 23        business         36
# 22           excel         34
# 106              e         33
# 96        academic         31
# 109     accounting         31
# 125      knowledge         30
# 158       prepared         27
# 66            team         25
# 39   communication         24
# 94         finance         24
# 137          learn         23
# 6             time         22
# 255        writing         21
# 50         project         19

# %%
sns.barplot(x='frequency',y='word',data=df3_Acad17)
# Out:
# <AxesSubplot:xlabel='frequency', ylabel='word'>

# %%
df3_Acad17_bi =Counter(ngrams(df3_2_A,2))
df3_Acad17_bi
# Out:
# Counter({('performance', 'relatively'): 1,
#          ('relatively', 'staticwe'): 1,
#          ('staticwe', 'much'): 1,
#          ('much', 'growth'): 1,
#          ('growth', 'responsibility'): 1,
#          ('responsibility', 'time'): 1,
#          ('time', 'however'): 1,
#          ('however', 'thats'): 1,
#          ('thats', 'due'): 1,
#          ('due', 'large'): 1,
#          ('large', 'part'): 1,
#          ('part', 'fact'): 1,
#          ('fact', 'first'): 1,
#          ('first', 'never'): 1,
#          ('never', 'experience'): 1,
#          ('experience', 'fastpaced'): 1,
#          ('fastpaced', 'corporate'): 1,
#          ('corporate', 'environment'): 2,
#          ('environment', 'expect'): 1,
#          ('expect', 'experience'): 1,
#          ('experience', 'sachins'): 1,
#          ('sachins', 'overall'): 1,
#          ('overall', 'excel'): 1,
#          ('excel', 'business'): 1,
#          ('business', 'intelligence'): 1,
#          ('intelligence', 'tool'): 1,
# ...

# %%
df3_Acad17_tri =Counter(ngrams(df3_2_A,3))
df3_Acad17_tri
# Out:
# Counter({('performance', 'relatively', 'staticwe'): 1,
#          ('relatively', 'staticwe', 'much'): 1,
#          ('staticwe', 'much', 'growth'): 1,
#          ('much', 'growth', 'responsibility'): 1,
#          ('growth', 'responsibility', 'time'): 1,
#          ('responsibility', 'time', 'however'): 1,
#          ('time', 'however', 'thats'): 1,
#          ('however', 'thats', 'due'): 1,
#          ('thats', 'due', 'large'): 1,
#          ('due', 'large', 'part'): 1,
#          ('large', 'part', 'fact'): 1,
#          ('part', 'fact', 'first'): 1,
#          ('fact', 'first', 'never'): 1,
#          ('first', 'never', 'experience'): 1,
#          ('never', 'experience', 'fastpaced'): 1,
#          ('experience', 'fastpaced', 'corporate'): 1,
#          ('fastpaced', 'corporate', 'environment'): 1,
#          ('corporate', 'environment', 'expect'): 1,
#          ('environment', 'expect', 'experience'): 1,
#          ('expect', 'experience', 'sachins'): 1,
# ...

# %%
df3_Acad17_tri1 = pd.DataFrame(df3_Acad17_tri.items(),columns=['word','frequency']).sort_values(by='frequency',ascending=False)

# %%
df3_Acad17_bi1 = pd.DataFrame(df3_Acad17_bi.items(),columns=['word','frequency']).sort_values(by='frequency',ascending=False)

# %%
df3_Acad17_tri1.head(30)
# Out:
#                                           word  frequency
# 70                        (valu, member, team)          4
# 71                       (member, team, happy)          3
# 418                     (concept, ed, perform)          3
# 417                  (accounting, concept, ed)          3
# 674                          (excel, pivot, t)          3
# 641                (variety, business, aspect)          2
# 1007            (investment, product, benefit)          2
# 130               (academic, program, prepare)          2
# 131                   (program, prepare, role)          2
# 132                (prepare, role, department)          2
# 133             (role, department, university)          2
# 1728                (happy, first, experience)          2
# 1727                      (team, happy, first)          2
# 1726                   (tatiana, valu, member)          2
# 1005         (increased, exposure, investment)          2
# ...

# %%
df3_Acad17_bi1.head(30)
# Out:
#                              word  frequency
# 335            (public, speaking)          8
# 509         (project, management)          8
# 187      (academically, prepared)          7
# 490              (data, analysis)          7
# 413         (accounting, concept)          5
# 329   (professional, environment)          4
# 130           (academic, program)          4
# 662                    (pivot, t)          4
# 230                  (finance, e)          4
# 71                 (member, team)          4
# 70                 (valu, member)          4
# 1464       (financial, statement)          3
# 655             (subject, matter)          3
# 410      (prepared, academically)          3
# 471            (time, management)          3
# 951           (experience, excel)          3
# 414                 (concept, ed)          3
# 415                 (ed, perform)          3
# 661                (excel, pivot)          3
# 674                      (co, op)          3
# ...

# %%
sns.barplot(x='frequency',y='word',data=df3_Acad17_tri1.head(30))
# Out:
# <AxesSubplot:xlabel='frequency', ylabel='word'>

# %%
sns.barplot(x='frequency',y='word',data=df3_Acad17_bi1.head(30))
# Out:
# <AxesSubplot:xlabel='frequency', ylabel='word'>

# %%
df4['Acad_R'] = df4['Acad'].str.replace("students","")

# %%
df4['Acad_R'] = df4['Acad_R'].str.replace("student","")
df4['Acad_R'] = df4['Acad_R'].str.replace("course","")
df4['Acad_R'] = df4['Acad_R'].str.replace("college","")
df4['Acad_R'] = df4['Acad_R'].str.replace("coop","")
df4['Acad_R'] = df4['Acad_R'].str.replace("preparation","")
df4['Acad_R'] = df4['Acad_R'].str.replace("additional","")
df4['Acad_R'] = df4['Acad_R'].str.replace("better","")
df4['Acad_R'] = df4['Acad_R'].str.replace("understanding","")
df4['Acad_R'] = df4['Acad_R'].str.replace("continued","")
df4['Acad_R'] = df4['Acad_R'].str.replace("skill","")
df4['Acad_R'] = df4['Acad_R'].str.replace("believe","")
df4['Acad_R'] = df4['Acad_R'].str.replace("suggest","")
df4['Acad_R'] = df4['Acad_R'].str.replace("improvement","")
df4['Acad_R'] = df4['Acad_R'].str.replace("improve","")
df4['Acad_R'] = df4['Acad_R'].str.replace("incorporate","")
df4['Acad_R'] = df4['Acad_R'].str.replace("more","")
df4['Acad_R'] = df4['Acad_R'].str.replace("drexel","")
df4['Acad_R'] = df4['Acad_R'].str.replace("none","")
df4['Acad_R'] = df4['Acad_R'].str.replace("na","")
df4['Acad_R'] = df4['Acad_R'].str.replace("would","")
df4['Acad_R'] = df4['Acad_R'].str.replace("work","")
df4['Acad_R'] = df4['Acad_R'].str.replace("class","")
df4['Acad_R'] = df4['Acad_R'].str.replace("need","")
df4['Acad_R'] = df4['Acad_R'].str.replace("major","")
df4['Acad_R'] = df4['Acad_R'].str.replace("continue","")
df4['Acad_R'] = df4['Acad_R'].str.replace("take","")
df4['Acad_R'] = df4['Acad_R'].str.replace("well","")
df4['Acad_R'] = df4['Acad_R'].str.replace("took","")
df4['Acad_R'] = df4['Acad_R'].str.replace("get","")
df4['Acad_R'] = df4['Acad_R'].str.replace("use","")
df4['Acad_R'] = df4['Acad_R'].str.replace("step","")

# %%
df4_1 = df4.drop(['Strengths', 'Weakness', 'Merged'], axis=1)

# %%
df4_1.head()
# Out:
#    Responder ID     Work Terms Major Concentration Class Citizenship   Coop  \
# 0           427  201815-201825   FIN          5COP    PJ   US Citizen     2
# 1           428  201815-201825   FIN          5COP    JR   US Citizen     3
# 2          1648  201815-201825   BAE          5COP    SR   US Citizen     3
# 3          1651  201815-201825  INT1          5COP    SR   US Citizen     3
# 4          1652  201815-201825   BAE          5COP    JR   US Citizen     3
#
#                                                 Acad  \
# 0                                               none
# 1  strengthen his knowledge of matters of corpora...
# 2                                               none
# 3  continue to take relevant classes and move to ...
# 4  better business communication in the workplace...
#
#                                               Acad_R
# 0
# 1  strengthen his knowledge of matters of corpora...
# 2
# 3   to  relevant es and move to insurance specifi...
# ...

# %%
# Printing lists of tokens (also known as lemmas) 
df4['Acad_R'] = df4['Acad_R'].apply(text_process)

# %%
wnl = nltk.WordNetLemmatizer()
def WNlemmatization(s):
    text = [wnl.lemmatize(r) for r in s]
    return text
df4['lemm_A1']  = df4['Acad_R'].apply(lambda x: WNlemmatization(x))

# %%
df4.head()
# Out:
#    Responder ID     Work Terms Major Concentration Class Citizenship   Coop  \
# 0           427  201815-201825   FIN          5COP    PJ   US Citizen     2
# 1           428  201815-201825   FIN          5COP    JR   US Citizen     3
# 2          1648  201815-201825   BAE          5COP    SR   US Citizen     3
# 3          1651  201815-201825  INT1          5COP    SR   US Citizen     3
# 4          1652  201815-201825   BAE          5COP    JR   US Citizen     3
#
#                                            Strengths  \
# 0  Sachin is dedicated to delivering high quality...
# 1  Positive outlook for work and interaction with...
# 2  - Very Bright; Absorbs & understands complicat...
# 3  Dedication, teamwork, quality performance, abi...
# 4  Reliable and persistent.  Han did not have the...
#
#                                             Weakness  \
# 0  Sachin can improve upon his confidence with pu...
# 1  Initiative and overall business / financial ac...
# ...

# %%
df4_1 = df4.drop(['Strengths', 'Weakness', 'Merged'], axis=1)

# %%
df4_1.head()
# Out:
#    Responder ID     Work Terms Major Concentration Class Citizenship   Coop  \
# 0           427  201815-201825   FIN          5COP    PJ   US Citizen     2
# 1           428  201815-201825   FIN          5COP    JR   US Citizen     3
# 2          1648  201815-201825   BAE          5COP    SR   US Citizen     3
# 3          1651  201815-201825  INT1          5COP    SR   US Citizen     3
# 4          1652  201815-201825   BAE          5COP    JR   US Citizen     3
#
#                                                 Acad  \
# 0                                               none
# 1  strengthen his knowledge of matters of corpora...
# 2                                               none
# 3  continue to take relevant classes and move to ...
# 4  better business communication in the workplace...
#
#                                               Acad_R  \
# 0                                                 []
# 1  [strengthen, knowledge, matters, corporate, fi...
# ...

# %%
df4_2_A = df4_1.lemm_A1.sum()
print(df4_2_A)
# Out:
# ['strengthen', 'knowledge', 'matter', 'corporate', 'fince', 'accounting', 'relevant', 'e', 'move', 'insurance', 'specific', 'desigtions', 'business', 'communication', 'place', 'data', 'alysis', 'telling', 'story', 'data', 'try', 'familiarize', 'technology', 'technical', 'great', 'set', 'shown', 'passion', 'learning', 'development', 'keep', 'momentum', 'going', 'definitely', 'go', 'far', 'ethan', 'always', 'harding', 'driven', 'intern', 'promptly', 'completes', 'task', 'efficiently', 'without', 'asking', 'much', 'back', 'ground', 'toward', 'end', 'internship', 'started', 'asking', 'question', 'engaging', 'discussion', 'strategic', 'process', 'optimization', 'initiative', 'program', 'around', 'changing', 'effect', 'technology', 'accountingfince', 'becoming', 'data', 'metric', 'using', 'technology', 'become', 'efficient', 'patrick', 'performs', 'due', 'also', 'due', 'passion', 'entrepreneurship', 'fincial', 'alysis', 'focus', 'fincial', 'room', 'activity', 'enhance', 'data', 'magement',
# ...

# %%
bow_df4_2_A = Counter(df4_2_A)
bow_df4_2_A
# Out:
# Counter({'strengthen': 1,
#          'knowledge': 9,
#          'matter': 3,
#          'corporate': 2,
#          'fince': 13,
#          'accounting': 16,
#          'relevant': 6,
#          'e': 18,
#          'move': 1,
#          'insurance': 2,
#          'specific': 6,
#          'desigtions': 1,
#          'business': 31,
#          'communication': 21,
#          'place': 6,
#          'data': 14,
#          'alysis': 8,
#          'telling': 1,
#          'story': 1,
#          'try': 2,
#          'familiarize': 1,
#          'technology': 6,
#          'technical': 7,
#          'great': 7,
#          'set': 4,
#          'shown': 2,
#          'passion': 3,
#          'learning': 8,
#          'development': 4,
#          'keep': 1,
#          'momentum': 1,
#          'going': 4,
#          'definitely': 2,
#          'go': 3,
#          'far': 1,
#          'ethan': 1,
#          'always': 2,
#          'harding': 1,
#          'driven': 1,
#          'intern': 1,
# ...

# %%
bow_df4_2_A1 = pd.DataFrame(bow_df4_2_A.items(),columns=['word','frequency']).sort_values(by='frequency',ascending=False)

# %%
bow_df4_2_A1.head(30)
# Out:
#               word  frequency
# 12        business         31
# 103          excel         25
# 13   communication         21
# 7                e         18
# 5       accounting         16
# 15            data         14
# 365       academic         14
# 215     experience         13
# 4            fince         13
# 210      marketing         12
# 80        magement         12
# 230           time         10
# 105        writing          9
# 140          think          9
# 1        knowledge          9
# 167           good          9
# 96         project          8
# 251        alytics          8
# 73            also          8
# 91        training          8
# 281         change          8
# 27        learning          8
# 16          alysis          8
# 505          first          8
# 23           great          7
# 199       prepared          7
# 125           team          7
# 152        benefit          7
# 308          basic          7
# 22       technical          7

# %%
df4_Acad18 =bow_df4_2_A1.head(20) #20 is top20
print(df4_Acad18)
# Out:
#               word  frequency
# 12        business         31
# 103          excel         25
# 13   communication         21
# 7                e         18
# 5       accounting         16
# 15            data         14
# 365       academic         14
# 215     experience         13
# 4            fince         13
# 210      marketing         12
# 80        magement         12
# 230           time         10
# 105        writing          9
# 140          think          9
# 1        knowledge          9
# 167           good          9
# 96         project          8
# 251        alytics          8
# 73            also          8
# 91        training          8

# %%
sns.barplot(x='frequency',y='word',data=df4_Acad18)
# Out:
# <AxesSubplot:xlabel='frequency', ylabel='word'>

# %%
df4_Acad18_bi =Counter(ngrams(df4_2_A,2))
df4_Acad18_bi
# Out:
# Counter({('strengthen', 'knowledge'): 1,
#          ('knowledge', 'matter'): 1,
#          ('matter', 'corporate'): 1,
#          ('corporate', 'fince'): 2,
#          ('fince', 'accounting'): 3,
#          ('accounting', 'relevant'): 1,
#          ('relevant', 'e'): 1,
#          ('e', 'move'): 1,
#          ('move', 'insurance'): 1,
#          ('insurance', 'specific'): 1,
#          ('specific', 'desigtions'): 1,
#          ('desigtions', 'business'): 1,
#          ('business', 'communication'): 2,
#          ('communication', 'place'): 1,
#          ('place', 'data'): 1,
#          ('data', 'alysis'): 3,
#          ('alysis', 'telling'): 1,
#          ('telling', 'story'): 1,
#          ('story', 'data'): 1,
#          ('data', 'try'): 1,
#          ('try', 'familiarize'): 1,
#          ('familiarize', 'technology'): 1,
#          ('technology', 'technical'): 1,
#          ('technical', 'great'): 1,
#          ('great', 'set'): 1,
#          ('set', 'shown'): 1,
# ...

# %%
df4_Acad18_tri =Counter(ngrams(df4_2_A,3))
df4_Acad18_tri
# Out:
# Counter({('strengthen', 'knowledge', 'matter'): 1,
#          ('knowledge', 'matter', 'corporate'): 1,
#          ('matter', 'corporate', 'fince'): 1,
#          ('corporate', 'fince', 'accounting'): 2,
#          ('fince', 'accounting', 'relevant'): 1,
#          ('accounting', 'relevant', 'e'): 1,
#          ('relevant', 'e', 'move'): 1,
#          ('e', 'move', 'insurance'): 1,
#          ('move', 'insurance', 'specific'): 1,
#          ('insurance', 'specific', 'desigtions'): 1,
#          ('specific', 'desigtions', 'business'): 1,
#          ('desigtions', 'business', 'communication'): 1,
#          ('business', 'communication', 'place'): 1,
#          ('communication', 'place', 'data'): 1,
#          ('place', 'data', 'alysis'): 1,
#          ('data', 'alysis', 'telling'): 1,
#          ('alysis', 'telling', 'story'): 1,
#          ('telling', 'story', 'data'): 1,
#          ('story', 'data', 'try'): 1,
#          ('data', 'try', 'familiarize'): 1,
# ...

# %%
df4_Acad18_tri1 = pd.DataFrame(df4_Acad18_tri.items(),columns=['word','frequency']).sort_values(by='frequency',ascending=False)

# %%
df4_Acad18_bi1 = pd.DataFrame(df4_Acad18_bi.items(),columns=['word','frequency']).sort_values(by='frequency',ascending=False)

# %%
df4_Acad18_tri1.head(30)
# Out:
#                                         word  frequency
# 3             (corporate, fince, accounting)          2
# 0            (strengthen, knowledge, matter)          1
# 1031                 (ready, assigned, task)          1
# 1041        (abigail, smart, recommendation)          1
# 1040             (requested, abigail, smart)          1
# 1039             (frame, requested, abigail)          1
# 1038                (time, frame, requested)          1
# 1037                   (within, time, frame)          1
# 1036                 (portion, within, time)          1
# 1035           (completing, portion, within)          1
# 1034         (followed, completing, portion)          1
# 1033            (task, followed, completing)          1
# 1032              (assigned, task, followed)          1
# 1030            (confident, ready, assigned)          1
# 1043          (recommendation, offer, place)          1
# 1029                 (got, confident, ready)          1
# ...

# %%
df4_Acad18_bi1.head(30)
# Out:
#                          word  frequency
# 905        (public, speaking)          4
# 4         (fince, accounting)          3
# 92            (accounting, e)          3
# 179         (business, world)          3
# 111       (project, magement)          3
# 144         (advanced, excel)          3
# 123             (business, e)          3
# 641       (accounting, fince)          3
# 514        (microsoft, excel)          3
# 15             (data, alysis)          3
# 768    (learning, experience)          2
# 1090            (first, year)          2
# 475          (time, magement)          2
# 89           (data, magement)          2
# 802        (experience, even)          2
# 543      (critical, thinking)          2
# 435          (focus, writing)          2
# 610          (prepared, role)          2
# 555                (fince, e)          2
# 247          (magement, show)          2
# 617           (ask, question)          2
# 698   (business, engineering)          2
# ...

# %%
sns.barplot(x='frequency',y='word',data=df4_Acad18_tri1.head(30))
# Out:
# <AxesSubplot:xlabel='frequency', ylabel='word'>

# %%
sns.barplot(x='frequency',y='word',data=df4_Acad18_bi1.head(30))
# Out:
# <AxesSubplot:xlabel='frequency', ylabel='word'>

# %%
df6['Acad_R'] = df6['Acad'].str.replace("students","")

# %%
df6['Acad_R'] = df6['Acad_R'].str.replace("student","")
df6['Acad_R'] = df6['Acad_R'].str.replace("course","")
df6['Acad_R'] = df6['Acad_R'].str.replace("college","")
df6['Acad_R'] = df6['Acad_R'].str.replace("coop","")
df6['Acad_R'] = df6['Acad_R'].str.replace("preparation","")
df6['Acad_R'] = df6['Acad_R'].str.replace("additional","")
df6['Acad_R'] = df6['Acad_R'].str.replace("better","")
df6['Acad_R'] = df6['Acad_R'].str.replace("understanding","")
df6['Acad_R'] = df6['Acad_R'].str.replace("continued","")
df6['Acad_R'] = df6['Acad_R'].str.replace("skill","")
df6['Acad_R'] = df6['Acad_R'].str.replace("believe","")
df6['Acad_R'] = df6['Acad_R'].str.replace("suggest","")
df6['Acad_R'] = df6['Acad_R'].str.replace("improvement","")
df6['Acad_R'] = df6['Acad_R'].str.replace("improve","")
df6['Acad_R'] = df6['Acad_R'].str.replace("incorporate","")
df6['Acad_R'] = df6['Acad_R'].str.replace("more","")
df6['Acad_R'] = df6['Acad_R'].str.replace("drexel","")
df6['Acad_R'] = df6['Acad_R'].str.replace("none","")
df6['Acad_R'] = df6['Acad_R'].str.replace("na","")
df6['Acad_R'] = df6['Acad_R'].str.replace("would","")
df6['Acad_R'] = df6['Acad_R'].str.replace("NaN","")

# %%
df6_1 = df6.drop(['Strengths', 'Weakness', 'merged'], axis=1)

# %%
df6_1.head()
# Out:
#    Responder ID     Work Terms Major Concentration Class BOT Citizenship  \
# 0          2181  Spring/Summer  ACCT          5COP        SR    Domestic
# 1            74    Fall/Winter   MIS          5COP        SR    Domestic
# 2          5586  Spring/Summer   FIN          5COP        SR    Domestic
# 3          2366  Spring/Summer   FIN          5COP        SR    Domestic
# 4          2367  Spring/Summer  MKTG          5COP        SR    Domestic
#
#    Coop                                               Acad  \
# 0     3                                                 na
# 1     3                                                NaN
# 2     2  just continue on the path of learning and take...
# 3     3                                                NaN
# 4     3                                               none
#
#                                               Acad_R
# 0
# 1                                                NaN
# 2  just continue on the path of learning and take...
# ...

# %%
from wordcloud import WordCloud
from wordcloud import STOPWORDS
 
# Wordcloud with positive tweets
Acad_15 = df1_Acad15
stop_words = ["https", "co", "RT"] + list(STOPWORDS)
positive_wordcloud = WordCloud(max_font_size=70, max_words=300, background_color="white", stopwords = stop_words).generate(str(Acad_15))
plt.figure()
plt.title("Acad 2015 - Wordcloud")
plt.imshow(positive_wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
Acad_16 = df2_Acad16
stop_words = ["https", "co", "RT"] + list(STOPWORDS)
positive_wordcloud = WordCloud(max_font_size=70, max_words=300, background_color="white", stopwords = stop_words).generate(str(Acad_16))
plt.figure()
plt.title("Acad 2016 - Wordcloud")
plt.imshow(positive_wordcloud, interpolation="bilinear")
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
Acad_17 = df3_Acad17
stop_words = ["https", "co", "RT"] + list(STOPWORDS)
positive_wordcloud = WordCloud(max_font_size=70, max_words=300, background_color="white", stopwords = stop_words).generate(str(Acad_17))
plt.figure()
plt.title("Acad 2017 - Wordcloud")
plt.imshow(positive_wordcloud, interpolation="bilinear")
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
Acad_18 = df4_Acad18
stop_words = ["https", "co", "RT"] + list(STOPWORDS)
positive_wordcloud = WordCloud(max_font_size=70, max_words=300, background_color="white", stopwords = stop_words).generate(str(Acad_18))
plt.figure()
plt.title("Acad 2018 - Wordcloud")
plt.imshow(positive_wordcloud, interpolation="bilinear")
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)
